# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Knowing the dataset

# %%
df= pd.read_csv("health insurance cross sell prediction.csv")
df
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1    Male   44                1         28.0                   0
# 1            2    Male   76                1          3.0                   0
# 2            3    Male   47                1         28.0                   0
# 3            4    Male   21                1         11.0                   1
# 4            5  Female   29                1         41.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
# ...

# %%
# Checking the top 10 rows of our dataset

df.head(10)
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
# 5   6  Female   24                1         33.0                   0
# 6   7    Male   23                1         11.0                   0
# 7   8  Female   56                1         28.0                   0
# 8   9  Female   24                1          3.0                   1
# 9  10  Female   32                1          6.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# ...

# %%
# Checking the bottom 10 rows of our dataset

df.tail(10)
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 381099  381100  Female   51                1         28.0                   0
# 381100  381101  Female   29                1         28.0                   0
# 381101  381102  Female   70                1         28.0                   0
# 381102  381103  Female   25                1         41.0                   1
# 381103  381104    Male   47                1         50.0                   0
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# ...

# %%
#To find data types using info- method 1

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %%
#To find data types using- method 2

df.dtypes
# Out:
# id                        int64
# Gender                   object
# Age                       int64
# Driving_License           int64
# Region_Code             float64
# Previously_Insured        int64
# Vehicle_Age              object
# Vehicle_Damage           object
# Annual_Premium          float64
# Policy_Sales_Channel    float64
# Vintage                   int64
# Response                  int64
# dtype: object

# %%
# To check the number of rows and columns of our dataset

df.shape
# Out:
# (381109, 12)

# %%
df.size
# Out:
# 4573308

# %%
# NUMERIC FEATURES
#To check the staststical figures

df.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# ...

# %% [markdown]
# How to check whether there are null values or not? (in the dataset)

# %%
df.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %% [markdown]
# From this we can infer that there are no null values in any of our columns of the dataset.  Hence, the process of dealing with null values or replacing with inferential statistics cannot be done(As there are no null values).

# %%
print(df.columns)
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')

# %% [markdown]
# This provides all the columns that are present in the dataset

# %%
# what are duplicate values and how to check duplicate values?

# %% [markdown]
# A duplicate value is one in which all values in at least one row are identical to all of the values in another row.
# How can duplicate values be removed or how to check only non-duplicate values?

# %%
df.nunique()
# Out:
# id                      381109
# Gender                       2
# Age                         66
# Driving_License              2
# Region_Code                 53
# Previously_Insured           2
# Vehicle_Age                  3
# Vehicle_Damage               2
# Annual_Premium           48838
# Policy_Sales_Channel       155
# Vintage                    290
# Response                     2
# dtype: int64

# %% [markdown]
# From the above method, we will be able to know only the NUMBER of unique values.

# %%
df.drop_duplicates(subset=['Vehicle_Age'])
# Out:
#    id Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1   Male   44                1         28.0                   0
# 1   2   Male   76                1          3.0                   0
# 3   4   Male   21                1         11.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 3    < 1 Year             No         28619.0                 152.0      203
#
#    Response
# 0         1
# 1         0
# 3         0

# %% [markdown]
# There are only three values for vehicle age , and these are repeated in the dataset. So, repeated values are removed and the unique values are printed. [This Method prints the required output in a Tabular form]

# %%
df
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1    Male   44                1         28.0                   0
# 1            2    Male   76                1          3.0                   0
# 2            3    Male   47                1         28.0                   0
# 3            4    Male   21                1         11.0                   1
# 4            5  Female   29                1         41.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
# ...

# %% [markdown]
# # What Analysis can be done in this?

# %% [markdown]
# Let us consider a column "Annual_Premium", now let us see the highest and least annual premium paid by the customers and their IDs'.

# %%
df['Annual_Premium'].max()
# Out:
# 540165.0

# %%
print('The highest annual premium paid by a person is: {}'.format(df['Annual_Premium'].max()),'\n','The Id of the person is: {}'.format(df.iloc[df['Annual_Premium'].idxmax()]['id']))
# Out:
# The highest annual premium paid by a person is: 540165.0
#  The Id of the person is: 54744

# %% [markdown]
# This is the highest annual premium paid by the customer with ID: 54744

# %%
df['Annual_Premium'].min()
# Out:
# 2630.0

# %%
print('The least annual premium paid by a person is: {}'.format(df['Annual_Premium'].min()),'\n','The Id of the person is: {}'.format(df.iloc[df['Annual_Premium'].idxmin()]['id']))
# Out:
# The least annual premium paid by a person is: 2630.0
#  The Id of the person is: 6

# %% [markdown]
# This is the least annual premium paid by the customer with ID: 6

# %% [markdown]
# #### Instead of checking the least and highest premium by seeing from the dataset,
# #### It can also be done by.

# %%
print(df[df['id']==54744])
# Out:
#           id Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 54743  54744   Male   26                1         28.0                   0
#
#       Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 54743    < 1 Year            Yes        540165.0                 156.0
#
#        Vintage  Response
# 54743      245         1

# %%
print(df[df['id']==6])
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 5   6  Female   24                1         33.0                   0
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 5    < 1 Year            Yes          2630.0                 160.0      176
#
#    Response
# 5         0

# %% [markdown]
# # Boxplot Method to spot the Outliers

# %%
sns.boxplot(df['Vintage'])
# Out:
# <AxesSubplot:xlabel='Vintage'>

# %% [markdown]
# From the above method of spotting the outliers for individual column, it can be clearly inferred that NO OUTLIERS are present in the column VINTAGE

# %%
cols = 5
rows = 5
num_cols = df.select_dtypes(exclude='object').columns
fig = plt.figure(figsize= (15,9))
for i, col in enumerate(num_cols):
    
    ax=fig.add_subplot( rows, cols, i+1)
    
    sns.boxplot(x=df[col], ax=ax)
    
fig.tight_layout()  
plt.show()


#Here, the numerical columns must be selected in order to visualise the histplot. For that, Datatypes like 'Object'
#(i.e, categorical) need to be excluded from the process of importing.
# Note: 'plt.show()' is a mandatory command in order to print the executed process.

# %% [markdown]
# From the above method of spotting the outliers for all columns together, it can be clearly inferred that OUTLIERS are present in the columns [Driving License], [Annual Premium], and [Response]. Rest of the columns DO NOT contain any outliers.

# %% [markdown]
# # Method of removing outliers from the visualised boxplot:

# %% [markdown]
# Sometimes a dataset can contain extreme values that are outside the range of what is expected and unlike the other data. These are called outliers and often machine learning modeling and model skill in general can be improved by understanding and even removing these outlier values.
#
#
# This does not mean that the values identified are outliers and should be removed.

# %% [markdown]
# For example, If we consider the column "Annual_Premium", there are n number of outliers. But, if we observe the column ANNUAL PREMIUM refers to "The Premium paid by a customer annually". If a person X paid the highest annual premium is considered to be an outlier and removed, The mean value of the column gets affected.
#
#
#
# So, Removing Outliers all the time is not a good method.

# %% [markdown]
# ### Spotting the Outliers:

# %%
np.where(df['Annual_Premium']>60000)
# Out:
# (array([    25,     37,     67, ..., 381047, 381068, 381079], dtype=int64),)

# %%
np.where(df['Response']==1)
# Out:
# (array([     0,      2,      7, ..., 381073, 381075, 381097], dtype=int64),)

# %% [markdown]
# ### Spotting the outliers using Z-Score method:

# %%
from scipy import stats
import numpy as np
 
z = np.abs(stats.zscore(df['Driving_License']))
print(z)
# Out:
# 0         0.046208
# 1         0.046208
# 2         0.046208
# 3         0.046208
# 4         0.046208
#             ...
# 381104    0.046208
# 381105    0.046208
# 381106    0.046208
# 381107    0.046208
# 381108    0.046208
# Name: Driving_License, Length: 381109, dtype: float64

# %% [markdown]
# ### Spotting the Outliers using IQR method:

# %%
Q1 = np.percentile(df['Driving_License'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(df['Driving_License'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1
# Above Upper bound
upper = df['Driving_License'] >= (Q3+1.5*IQR)
 
print("Upper bound:",upper)
print(np.where(upper))
 
# Below Lower bound
lower = df['Driving_License'] <= (Q1-1.5*IQR)
print("Lower bound:", lower)
print(np.where(lower))
# Out:
# Upper bound: 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 381104    True
# 381105    True
# 381106    True
# 381107    True
# 381108    True
# Name: Driving_License, Length: 381109, dtype: bool
# (array([     0,      1,      2, ..., 381106, 381107, 381108], dtype=int64),)
# Lower bound: 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 381104    True
# 381105    True
# 381106    True
# 381107    True
# 381108    True
# Name: Driving_License, Length: 381109, dtype: bool
# (array([     0,      1,      2, ..., 381106, 381107, 381108], dtype=int64),)

# %% [markdown]
# # Knowing the Categorical (Non-Numerical) Columns.

# %%
df.describe(include= 'object')
# Out:
#         Gender Vehicle_Age Vehicle_Damage
# count   381109      381109         381109
# unique       2           3              2
# top       Male    1-2 Year            Yes
# freq    206089      200316         192413

# %% [markdown]
# It can be inferred that there are only 3 columns of the data-type "object".

# %% [markdown]
# # Checking The percentage of Male and Female using PIE CHART

# %%
data= df['Gender'].value_counts()
plt.pie(data, labels=data.index, autopct= "%.0f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1ad6e19f880>,
# ...
#  [Text(-0.14047625142251505, 1.0909933193133121, 'Male'),
#   Text(0.14047625142251538, -1.0909933193133121, 'Female')],
#  [Text(-0.07662340986682638, 0.5950872650799883, '54%'),
#   Text(0.07662340986682657, -0.5950872650799883, '46%')])

# %% [markdown]
# From this, it can be clearly inferred that the Male percentage is more than Female percentage. This comes under Univariate Categorical Analysis because, there are no numerical entries in the column "Gender".

# %% [markdown]
# # Using Countplot, finding the Types and Number in the column Vehicle Age.

# %%
sns.countplot(df['Vehicle_Age'])
# Out:
# <AxesSubplot:xlabel='Vehicle_Age', ylabel='count'>

# %% [markdown]
# From this, Most of the people's Vehicle Age is from 1-2 years.

# %% [markdown]
# # Using horizontal barplot, knowing the Column Vehicle Damage.

# %%
df['Vehicle_Damage'].value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# From this, it can be said that there are more number of people with Vehicle Damage.

# %% [markdown]
# # Normalization Technique

# %% [markdown]
# Let us consider the column Gender.

# %%
df.Gender.value_counts().plot.pie()
plt.show()

df.Gender.value_counts(normalize= True)
# Out:
# Male      0.540761
# Female    0.459239
# Name: Gender, dtype: float64

# %% [markdown]
# The Values are normalised to produce the sum of 1.
#
# Normalization is the process to eliminate data redundancy and enhance data integrity in the table. Normalization also helps to organize the data in the database

# %% [markdown]
# # Removing a Column for barplot

# %%
df[~(df.Vehicle_Age== "> 2 Years")].Vehicle_Age.value_counts(normalize=True).plot.barh()
plt.show()

# %% [markdown]
# Previously, there are three bars of three different columns. One is removed and the other 2 are printed.

# %% [markdown]
# # Random Univariate Analytical Visualisation

# %% [markdown]
# ### 1. Histplot

# %%
sns.histplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
#Importing Matplot library in order to visualise the data in barplot

import matplotlib.pyplot as plt

cols = 5
rows = 5
num_cols = df.select_dtypes(exclude='object').columns
fig = plt.figure( figsize=(cols*5, rows*5))
for i, col in enumerate(num_cols):
#for i in num_cols:    
    ax=fig.add_subplot(rows,cols,i+1)
    
    sns.histplot(x = df[col], ax = ax)
    
fig.tight_layout()  
plt.show()

#Here, the numerical columns must be selected in order to visualise the histplot. For that, Datatypes like 'Object'
#(i.e, categorical) need to be excluded from the process of importing.
# Note: 'plt.show()' is a mandatory command in order to print the executed process.

# %% [markdown]
# ### 2. Kernel Density Plot

# %%
sns.kdeplot(x='Vintage',data=df, hue= 'Gender')
# Out:
# <AxesSubplot:xlabel='Vintage', ylabel='Density'>

# %% [markdown]
# This is a method to represent KDE plot for a single column.

# %%
import matplotlib.pyplot as plt

cols = 5
rows = 5
num_cols = df.select_dtypes(exclude='object').columns
fig = plt.figure( figsize=(cols*5, rows*5))
for i, col in enumerate(num_cols):
   
    ax=fig.add_subplot(rows,cols,i+1)
    
    sns.kdeplot(x = df[col], ax = ax, hue= True)
    
fig.tight_layout()  
plt.show()

# %% [markdown]
# This is a method to represent KDE plot for all numerical columns.

# %% [markdown]
# ### 3. Violin Plot

# %%
sns.violinplot(df['Annual_Premium'])
# Out:
# <AxesSubplot:xlabel='Annual_Premium'>

# %%
num_cols = df.select_dtypes(exclude='object').columns
cols = 3
rows = 3
fig = plt.figure( figsize=(cols*3, rows*3))
for i, col in enumerate(num_cols):
   
    ax=fig.add_subplot(rows,cols,i+1)
    
    sns.violinplot(x = df[col], ax = ax, hue= True)
    
fig.tight_layout()  
plt.show()

# %% [markdown]
# ### 4. Strip Plot

# %%
sns.stripplot(df['Annual_Premium'])
# Out:
# <AxesSubplot:xlabel='Annual_Premium'>

# %% [markdown]
# A strip plot is a single-axis scatter plot that is used to visualise the distribution of many individual one-dimensional values. The values are plotted as dots along one unique axis, and the dots with the same value can overlap.

# %%
num_cols = df.select_dtypes(exclude='object').columns
cols = 4
rows = 4
fig = plt.figure( figsize=(cols*3, rows*3))
for i, col in enumerate(num_cols):
   
    ax=fig.add_subplot(rows,cols,i+1)
    
    sns.stripplot(x = df[col], ax = ax, hue= True)
    
fig.tight_layout()  
plt.show()

# %% [markdown]
# ### After all the visualsation of Univariate columns, it can be inferred that:

# %% [markdown]
# 1) Columns "Driving License", "Previously Insured" and "Response" have only two values i.e, either 0 or 1.

# %% [markdown]
# 2) Most people are aged from 20-80. Above the age 80, there are very few people.

# %% [markdown]
# 3) Majority of the customers are paying an annual premium of 0-200000

# %% [markdown]
# # Bi- Variate Analysis

# %% [markdown]
# Bivariate analysis is stated to be an analysis of any concurrent relation between two variables or attributes. This study explores the relationship of two variables as well as the depth of this relationship to figure out if there are any discrepancies between two variables and any causes of this difference.

# %% [markdown]
# ### Finding the relationship between two columns using PAIRPLOT:

# %% [markdown]
# A pairplot plot a pairwise relationships in a dataset. The pairplot function creates a grid of Axes such that each variable in data will by shared in the y-axis across a single row and in the x-axis across a single column.

# %%
sns.pairplot(df)

# %% [markdown]
# From the above Pairplot,
# 1. Most of the people are having response 0.
# 2. If the customer is having no driving license, he/she is considered as 0. Else, he/she is considered as 1.

# %% [markdown]
# ### Finding the relationship between "Vintage" and "Annual_Premium" using SCATTERPLOT :

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['Vintage'], df['Annual_Premium'])
 
# x-axis label
ax.set_xlabel('Vintage')
 
# y-axis label
ax.set_ylabel('Annual_Premium')
plt.show()

# %% [markdown]
# ### Visualising the relationship between the two columns using Barplot:

# %%
sns.barplot(x='Annual_Premium',y='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Annual_Premium', ylabel='Gender'>

# %% [markdown]
# Barplot can be done for single variable and two  variables also.

# %% [markdown]
# ### Heatmap representation to find Correlation

# %%
corr= df.corr()
plt.figure(figsize=(10,6))
sns.heatmap(corr, square=True)
plt.show()

# %%
sns.lineplot(data=df)
plt.show()

# %% [markdown]
# After all the visualsation of Bivariate columns, it can be inferred that:
#
# 1) The least paid annual premium is 2630 by the customer with ID: 6.
#
# 2) Most people who are previously insured might or might not have driving license .
#
# 3) There are only few people who are paying annual premium more than 500000.

# %% [markdown]
# ## Inferential Statistics

# %%
x= df.Annual_Premium.mean()
x
# Out:
# 30564.389581458323

# %%
y=df.Vintage.mode()
y
# Out:
# 0    256
# dtype: int64

# %%
z=df.Policy_Sales_Channel.median()
z
# Out:
# 133.0

# %%
sum= (x+y+z)/3
print("The average value of Mean, median and mode is: ",sum)
# Out:
# The average value of Mean, median and mode is:  0    10317.796527
# dtype: float64

# %% [markdown]
# # How many customers are above the age 30?

# %%
(df['Age']>30).value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### From this, we can ensure that more than 200000 customers
# #### are above the age 30, and around 160000 customers are below the age 30.

# %% [markdown]
# # Finding How many members are previously Insured

# %%
sns.countplot(df['Previously_Insured'])
# Out:
# <AxesSubplot:xlabel='Previously_Insured', ylabel='count'>

# %% [markdown]
# ##### From the above count plot, about 200000 members
# ##### are not previously insured with vehicle Insurance,
# ##### where as the remaining people i.e, around 170000
# ##### members are already previously insured with Insurance.

# %% [markdown]
# # To relate the Gender and Vehicle Damage.

# %%
sns.countplot(x='Gender',data=df, hue= 'Vehicle_Damage')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### From the above plot, we can find the number of Male and Female
# #### having Vehicle damage, Not having Vehicle Damage.

# %% [markdown]
# # Plotting All the categorical columns on Countplot Once.

# %%
import matplotlib.pyplot as plt
cols = 3
rows = 1
fig = plt.figure(figsize= (10,6))
all_categs = df.select_dtypes(include='object')
cat_cols = all_categs.columns[all_categs.nunique() < 10]
for i, col in enumerate(cat_cols):
    ax=fig.add_subplot(rows, cols, i+1)
    sns.countplot(x=df[col], ax=ax)
    plt.xticks(rotation=0, ha='right')
    
fig.tight_layout()  
plt.show()

# %% [markdown]
# #### From the above method ....
# 1) Number of Male > Number of Female.
#
#
# 2) No. of people having their "Vehicle Damaged" is almost equal to No. of people having their "vehicle Undamaged".
#
#
# 3) Majority of the the people are using their vehicle for 1-2 years.
#
#
# 4) Very few people's vehicle age is more than 2 years.

# %% [markdown]
# ### Let us Check the percentage of people having their vehicle
# ### age> 2yrs vs having their vehicle age<1yr vs having their
# ### vehicle age between 1-2yrs.

# %%
df['Vehicle_Age'].value_counts()
# Out:
# 1-2 Year     200316
# < 1 Year     164786
# > 2 Years     16007
# Name: Vehicle_Age, dtype: int64

# %%
data= df['Vehicle_Age'].value_counts()
plt.pie(data, labels=data.index, autopct= "%.0f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x297db58cc70>,
# ...
#  [Text(-0.0884181610264175, 1.096440709204427, '1-2 Year'),
#   Text(-0.0566067121881008, -1.0985425254104884, '< 1 Year'),
#   Text(1.0904378981683174, -0.14472453226133553, '> 2 Years')],
#  [Text(-0.04822808783259136, 0.59805856865696, '53%'),
#   Text(-0.030876388466236797, -0.5992050138602664, '43%'),
#   Text(0.5947843080918095, -0.07894065396072847, '4%')])

# %% [markdown]
# ### Finding the most repeated value of Region Code

# %%
df['Region_Code'].value_counts().max()
# Out:
# 106415

# %%
print(df[df['Region_Code']==28.0])
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1    Male   44                1         28.0                   0
# 2            3    Male   47                1         28.0                   0
# 7            8  Female   56                1         28.0                   0
# 13          14    Male   76                1         28.0                   0
# 14          15    Male   71                1         28.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 381095  381096    Male   52                1         28.0                   0
# 381097  381098  Female   38                1         28.0                   0
# 381099  381100  Female   51                1         28.0                   0
# 381100  381101  Female   29                1         28.0                   0
# 381101  381102  Female   70                1         28.0                   0
#
# ...

# %% [markdown]
# ### Finding the Mean/Median/Mode using Sklearn Simple Imputation

# %%
from sklearn.impute import SimpleImputer

# %%
impo = SimpleImputer(strategy='mean')
x = df[['Annual_Premium']]
X = impo.fit_transform(x)
print(X)
# Out:
# [[40454.]
#  [33536.]
#  [38294.]
#  ...
#  [35118.]
#  [44617.]
#  [41777.]]

# %%
impo = SimpleImputer(strategy='most_frequent')
y = df[['Annual_Premium']]
Y = impo.fit_transform(y)
print(Y)
# Out:
# [[40454.]
#  [33536.]
#  [38294.]
#  ...
#  [35118.]
#  [44617.]
#  [41777.]]

# %% [markdown]
# The three common measures of central tendency of a distribution are
#
# the arithmetic mean, the median and the mode. Think of a distribution
#
# in terms of an histogram with many bars. A large sample from a normal
#
# distribution would describe a bell shaped curve that is symmetrical.
#
# In a non-skewed distribution the mean, median
#
# and mode are equal.

# %%
sns.distplot(df['Annual_Premium'])
# Out:
# <AxesSubplot:xlabel='Annual_Premium', ylabel='Density'>

# %%
sns.boxplot(df['Annual_Premium'])
# Out:
# <AxesSubplot:xlabel='Annual_Premium'>

# %% [markdown]
# # Removing the Outliers after the whole analysis.

# %%
Q1 = np.percentile(df['Annual_Premium'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(df['Annual_Premium'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1
 
print("Old Shape: ", df.shape)
 
# Upper bound
upper = np.where(df['Annual_Premium'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(df['Annual_Premium'] <= (Q1-1.5*IQR))
 
''' Removing the Outliers '''
df.drop(upper[0], inplace = True)
df.drop(lower[0], inplace = True)
 
print("New Shape: ", df.shape)
# Out:
# Old Shape:  (381109, 12)
# New Shape:  (370789, 12)

# %%
sns.boxplot(df['Annual_Premium'])
# Out:
# <AxesSubplot:xlabel='Annual_Premium'>

# %%
df['Annual_Premium'].max()
# Out:
# 61892.0

# %% [markdown]
# Previously before removing the outliers,
#
# the highest Annual Premium is 540165.
#
# Now the Annual Premium is 61892.
#
# It means the person who paid the
#
# annual premium is considered as an outlier.

# %%
x=df['Annual_Premium'].mean()
y=df['Annual_Premium'].mode()
z=df['Annual_Premium'].median()

print("mean: ",x)
print("mode: ",y)

print("median: ",z)
# Out:
# mean:  29264.643972717637
# mode:  0    2630.0
# dtype: float64
# median:  31319.0

# %% [markdown]
# The values of Mean, Median, Mode also got affected.
#
# Hence, Removal of outliers is not suggested in every case.

# %%
sns.distplot(df['Annual_Premium'])
# Out:
# <AxesSubplot:xlabel='Annual_Premium', ylabel='Density'>

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# Multivariate analysis is based in observation and analysis of more than one statistical outcome variable at a time. In design and analysis, the technique is used to perform trade studies across multiple dimensions while taking into account the effects of all variables on the responses of interest. The development of multivariate methods emerged to analyze large databases and increasingly complex data.
#
#
# Since the best way to represent the knowledge of reality is the modeling, we should use multivariate statistical methods. Multivariate methods are designed to simultaneously analyze data sets, i.e., the analysis of different variables for each person or object studied. Keep in mind at all times that all variables must be treated accurately reflect the reality of the problem addressed. There are different types of multivariate analysis and each one should be employed according to the type of variables to analyze: dependent, interdependence and structural methods. In conclusion, multivariate methods are ideal for the analysis of large data sets and to find the cause and effect relationships between variables; there is a wide range of analysis types that we can use.

# %% [markdown]
# Multivariate analysis in a broad sense is the set of statistical methods aimed simultaneously analyze datasets. That is, for each individual or object being studied, analyzed several variables. The essence of multivariate thinking is to expose the inherent structure and meaning revealed within these sets if variables through application and interpretation of various statistical methods.

# %%
sns.boxplot(data=df.loc[:,['Policy_Sales_Channel','Annual_Premium','Vintage']])
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here, we have just analsysed only 3 of the columns together i.e, 'Annual Premium', 'Policy_Sales_Channel', and 'Vintage'.

# %%
sns.pairplot(df)

# %% [markdown]
# From the above Pair plot,
# 1. Most of the people are having response 0.
# 2. If the customer is having no driving license, he/she is considered as 0. Else, he/she is considered as 1.
# 3. Majority of the customers are paying an annual premium of 0-200000.
# 4. Most people are aged from 20-80. Above the age 80, there are very few people.
# This study explores the relationship of multiple variables.

# %%
sns.jointplot(data=df,x='Annual_Premium',y='Policy_Sales_Channel')

# %%
plt.figure(figsize=(15,10))
plt.title("Heatmap Relation b/w multiple columns")
corr=df.corr()
sns.heatmap(data=corr,annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# There are several variables that have no correlation and whose correlation value is near 0.
#
# A correlation heatmap is a graphical representation of a correlation matrix representing the correlation between different variables.
#
# The value of correlation can take any value from -1 to 1.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We looked at the definitions of univariate, bivariate, and multivariate analysis. We also looked at some ways to perform such analysis in python. We used some plots to identify relations between variables. We also understood how we can interpret the results of such analysis.
# Built a model to predict whether a customer would be interested in Vehicle Insurance is extremely helpful for the company because it can then accordingly plan its communication strategy to reach out to those customers and optimize its business model and revenue.
# Previously insured, Age, and Vehicle Damage are significant features.
# We got fewer Values where Previously Insured value equal to 1.
# In other words, most previous customers didn't buy the insurance. The company should consider the reason behind that result.
# The trigger should be communication strategy, irrelevant product, etc.
# Values get minor numbers, whereas vehicle damage gets a small value. We assume that situation is normal because people used not to think about insurance unless they got an accident.
# The company should consider starting a marketing campaign for that purpose.
# The insurance annual premium prices affected value 0.12, which needs considering and further research about pricing strategy.
